# %%
import sqlite3
import json
import time
import os

# Connecting to sqlite
conn = sqlite3.connect('../auchan_scrape.sqlite')
cursor = conn.cursor()

# %% [markdown]
# # Insert product

# %%
def construct_product(data):
    print(data["id"])
    return [
        data["id"],
        data["categoryId"],
        data["categoryName"],
        data["brandName"],
        data["defaultVariant"]["id"],
        data["selectedVariant"]["id"],
        data["eancode"],
        data["reviewable"],
        data["reviewSum"]["sumCount"],
        data["reviewSum"]["average"],
        data["isNewProduct"],
        data["adultsOnly"],
        data["shipmentDays"],
        data["ageConfirmed"],
        data["isNonFood"]
    ]

# %%
def insert_product(row_data):
    insert_command = """
    INSERT INTO products VALUES (
        ?,?,?,?,?,?,?,?,?,?,?,?,?,?,?
    )
    """
    try:
        cursor.execute(insert_command, row_data)
    except sqlite3.IntegrityError:
        pass

# %% [markdown]
# # Insert variants

# %%
def construct_price(variant_id, price_data, time):
    return [
        variant_id,
        price_data["net"],
        price_data["gross"],
        price_data["currency"],
        price_data["decimalPlaces"],
        price_data["netDiscounted"],
        price_data["grossDiscounted"],
        price_data["discountPercentage"],
        price_data["isDiscounted"],
        time
    ]

# %%
def construct_variant(variant_data):
    return [
        variant_data["id"],
        variant_data["name"],
        variant_data["sku"],
        variant_data["productId"],
        variant_data["addedName"],
        variant_data["selectValue"],
        variant_data["status"],
        variant_data["unit"],
        variant_data["eanCode"],
        variant_data["aided"],
        variant_data["loose"]["weightPerPiece"],
        variant_data["packageInfo"]["packageUnit"],
        variant_data["packageInfo"]["packageSize"]
    ]

# %%
def construct_nutrition(variant_id, nd):
    values = {
        "energia": "calories",
        "zsír": "fat",
        "telített": "saturated_fat",
        "szénhidrát": "carbohydrates",
        "cukrok": "sugar",
        "cukor": "sugar",
        "rost": "fiber",
        "fehérje": "protein",
        "só": "sodium"
    }
    row = {
        "variant_id": variant_id,
        "calories": 0,
        "fat": 0,
        "saturated_fat": 0,
        "carbohydrates": 0,
        "sugar": 0,
        "fiber": 0,
        "protein": 0,
        "sodium": 0
    }

    for field in nd:
        if field[0].lower().find("energia") != -1:
            row["calories"] = float(field[2].split("/")[1].strip().replace(",", "."))
        else:
            for key in values:
                if field[0].strip().split(" ")[0].lower().find(key) != -1:
                    value_string = field[2].strip()
                    if value_string != '':
                        row[values[key]] = float(value_string.replace(",", "."))
                    else:
                        row[values[key]] = 0
    # convert row to list in the same order as the table
    return [row["variant_id"], row["calories"], row["fat"], row["saturated_fat"], row["carbohydrates"], row["sugar"], row["fiber"], row["protein"], row["sodium"]]

# %%
def construct_stock_info(variant_id, stock_info, time):
    return [
        variant_id,
        stock_info["stock"],
        stock_info["store"]["id"],
        time
    ]

# %%
def construct_store(sd):
    return [
        sd["id"],
        sd["name"],
        sd["address"]["postCode"],
        sd["address"]["city"],
        sd["address"]["streetName"] + sd["address"]["streetType"] + " " + sd["address"]["streetNo"]
    ]

# %%
def gather_variants_info(filename, data):
    variant_rows = []
    price_rows = []
    nutrition_rows = []
    stock_rows = []
    store_rows = []
    for variant in ["defaultVariant", "selectedVariant"]:
        variant_data = data[variant]
        row_data = construct_variant(variant_data)

        price_data = variant_data["price"]
        price_row = construct_price(variant_data["id"], price_data, int(time.time()))

        with open(filename+"nutrition.json") as f:
            nutrition_data = json.loads(f.read())
        nutrition_row = construct_nutrition(variant_data["id"], nutrition_data["data"])
        nutrition_rows.append(nutrition_row)

        with open(filename+"stock_infos.json") as f:
            stock_data = json.loads(f.read())
        tmp_stock_rows = []
        for stock in stock_data:
            stock_row = construct_stock_info(variant_data["id"], stock, int(time.time()))
            store_row = construct_store(stock["store"])
            assert len(stock_row) == 4 and len(store_row) == 5
            tmp_stock_rows.append(stock_row)
            store_rows.append(store_row)
        stock_rows.append(tmp_stock_rows)

        assert len(row_data) == 13 and len(price_row) == 10
        variant_rows.append(row_data)
        price_rows.append(price_row)

    return {
        "variants": variant_rows,
        "prices": price_rows,
        "nutritions": nutrition_rows,
        "stocks": stock_rows,
        "stores": store_rows
    }

# %%
def insert_variant_data(variant_info):
    variant_rows = variant_info["variants"]
    price_rows = variant_info["prices"]
    nutrition_rows = variant_info["nutritions"]
    stock_rows = variant_info["stocks"]
    store_rows = variant_info["stores"]

    variant_insert_command = """
    INSERT INTO variants VALUES (
        ?,?,?,?,?,?,?,?,?,?,?,?,?
    )
    """
    price_insert_command = """
    INSERT INTO prices VALUES (
        ?,?,?,?,?,?,?,?,?,?
    )
    """
    nutrition_insert_command = """
    INSERT INTO nutritions VALUES (
        ?,?,?,?,?,?,?,?,?
    )
    """
    stock_insert_command = """
    INSERT INTO stock_infos VALUES (
        ?,?,?,?
    )
    """
    store_insert_command = """
    INSERT INTO stores VALUES (
        ?,?,?,?,?
    )
    """
    for i, row in enumerate(variant_rows):
        try:
            cursor.execute(variant_insert_command, row)

            price = price_rows[i]
            cursor.execute(price_insert_command, price)
            nutrition_row = nutrition_rows[i]
            cursor.execute(nutrition_insert_command, nutrition_row)

            for stock in stock_rows[i]:
                cursor.execute(stock_insert_command, stock)

        except sqlite3.IntegrityError:
            print(f'row: {row[0]} already exists')

    for store in store_rows:
        try:
            cursor.execute(store_insert_command, store)
        except sqlite3.IntegrityError:
            pass

# %%
def construct_categories(categories_data):
    categories = []
    for category_data in categories_data:
        category_row = [
            category_data["id"],
            category_data["name"],
            category_data["productCount"],
            category_data["discountedCount"],
            category_data["childCount"],
            category_data["slug"]
        ]
        assert len(category_row) == 6
        categories.append(category_row)
    return categories

# %%
def insert_categories(data, categories):
    category_insert_command = """
    INSERT INTO categories VALUES (
        ?,?,?,?,?,?
    )
    """

    category_connect_command = """
    INSERT INTO product_to_categories VALUES (
        ?,?
    )
    """

    for category in categories:
        try:
            cursor.execute(category_insert_command, category)
            cursor.execute(category_connect_command, (data["id"], category[0]))
        except sqlite3.IntegrityError:
            pass

# %%
def start_loop():
    # for all subdirectory in base directory: ../rawdata/
    for product in os.listdir("../rawdata/"):
        # for all files in subdirectory
        for variant in os.listdir("../rawdata/"+product):
            filename = "../rawdata/"+product+"/"+variant+"/"
            with open(filename+"product.json") as f:
                data = json.loads(f.read())
                try:
                    variants_data = gather_variants_info(filename, data)
                except FileNotFoundError:
                    print("no nutrition_data", filename)
                    continue
                except ValueError:
                    print("wrong format", filename)
                    continue
                except IndexError:
                    #print(data)
                    print(filename)
                    break
                try:
                    product_data = construct_product(data)
                except KeyError:
                    print(data["id"])
                    break
                insert_product(product_data)
                insert_variant_data(variants_data)
                insert_categories(data, construct_categories(data["categories"]))
    conn.commit()

# %%
start_loop()
# Out:
# 14908
# row: 14911 already exists
# 14911
# row: 14914 already exists
# 425635
# row: 3963016 already exists
# 19996
# row: 19999 already exists
# 524806
# row: 4062196 already exists
# 464410
# row: 4001800 already exists
# 464407
# row: 4001797 already exists
# 451057
# row: 3988447 already exists
# 409472
# row: 3946829 already exists
# 451075
# row: 3988465 already exists
# 67478
# row: 3604559 already exists
# 32170
# row: 32173 already exists
# 32164
# row: 32167 already exists
# 25906
# row: 25909 already exists
# 25903
# row: 25906 already exists
# 524797
# row: 4062187 already exists
# 524800
# row: 4062190 already exists
# 524803
# row: 4062193 already exists
# 38803
# row: 38806 already exists
# 32167
# row: 32170 already exists
# 24877
# row: 24880 already exists
# 21463
# row: 21466 already exists
# 451993
# 451993
# 67481
# row: 3604562 already exists
# 391689
# row: 3928974 already exists
# 391692
# row: 3928977 already exists
# ../rawdata/208599/3745845/
# ../rawdata/207370/3744619/
# ../rawdata/207367/3744616/
# wrong format ../rawdata/207364/3744613/
# wrong format ../rawdata/207358/3744607/
# wrong format ../rawdata/208602/3745848/
# 150424
# row: 3687670 already exists
# wrong format ../rawdata/41146/41149/
# no nutrition_data ../rawdata/582178/4119568/
# 34327
# row: 34330 already exists
# 190414
# row: 3727663 already exists
# 530494
# row: 4067884 already exists
# 484142
# row: 4021529 already exists
# 33799
# row: 33802 already exists
# 68105
# row: 3605186 already exists
# 5281
# row: 5284 already exists
# 409475
# row: 3946832 already exists
# 99690
# row: 3636894 already exists
# 468398
# 468398
# 501815
# row: 4039211 already exists
# 100093
# row: 3637300 already exists
# 100102
# row: 3637309 already exists
# 501818
# row: 4039214 already exists
# 580579
# 580579
# 100096
# row: 3637303 already exists
# 493777
# row: 4031185 already exists
# 99471
# row: 3636675 already exists
# 100090
# row: 3637297 already exists
# 16672
# row: 16675 already exists
# 100087
# row: 3637294 already exists
# 19594
# row: 19597 already exists
# 100099
# row: 3637306 already exists
# 97741
# row: 3634815 already exists
# 468401
# 468401
# 103160
# row: 3640361 already exists
# 553569
# row: 4090959 already exists
# 27970
# row: 27973 already exists
# 23608
# row: 23611 already exists
# 17557
# row: 17560 already exists
# 22039
# row: 22042 already exists
# 193517
# row: 3730760 already exists
# 4465
# row: 4465 already exists
# 193520
# row: 3730763 already exists
# 580408
# row: 4117798 already exists
# 468821
# 468821
# 41617
# row: 41620 already exists
# 206716
# row: 3743965 already exists
# 468824
# 468824
# 23611
# row: 23614 already exists
# 100105
# row: 3637312 already exists
# 186847
# row: 3724093 already exists
# 424891
# row: 3962272 already exists
# 425098
# row: 3962479 already exists
# 13663
# row: 13666 already exists
# 424894
# row: 3962275 already exists
# 99801
# row: 3637005 already exists
# no nutrition_data ../rawdata/490459/4027855/
# no nutrition_data ../rawdata/490450/4027843/
# no nutrition_data ../rawdata/490474/4027873/
# no nutrition_data ../rawdata/490453/4027849/
# no nutrition_data ../rawdata/490498/4027897/
# no nutrition_data ../rawdata/13366/13369/
# no nutrition_data ../rawdata/425194/3962575/
# no nutrition_data ../rawdata/425191/3962572/
# no nutrition_data ../rawdata/425197/3962578/
# no nutrition_data ../rawdata/425182/3962563/
# 498787
# row: 4036189 already exists
# no nutrition_data ../rawdata/441352/3978736/
# 498820
# row: 4036222 already exists
# no nutrition_data ../rawdata/425188/3962569/
# 498829
# row: 4036231 already exists
# no nutrition_data ../rawdata/425179/3962560/
# 498832
# row: 4036234 already exists
# no nutrition_data ../rawdata/425176/3962557/
# wrong format ../rawdata/545878/4083268/
# no nutrition_data ../rawdata/425185/3962566/
# 498814
# row: 4036216 already exists
# no nutrition_data ../rawdata/73407/3610495/
# 498817
# row: 4036219 already exists
# no nutrition_data ../rawdata/103762/3640954/
# 498793
# row: 4036195 already exists
# no nutrition_data ../rawdata/411022/3948388/
# 498811
# row: 4036213 already exists
# no nutrition_data ../rawdata/73409/3610497/
# 498784
# row: 4036186 already exists
# no nutrition_data ../rawdata/441355/3978739/
# 498802
# row: 4036204 already exists
# 65669
# row: 3602750 already exists
# 9283
# row: 9286 already exists
# 16723
# row: 16726 already exists
# 51360
# row: 51702 already exists
# 51363
# row: 51705 already exists
# 9277
# row: 9280 already exists
# 13027
# row: 13030 already exists
# no nutrition_data ../rawdata/508867/4046257/
# 15460
# row: 15463 already exists
# no nutrition_data ../rawdata/105802/3642997/
# 40423
# row: 40426 already exists
# no nutrition_data ../rawdata/121498/3658693/
# 444355
# row: 3981739 already exists
# no nutrition_data ../rawdata/121495/3658690/
# 393793
# row: 3931093 already exists
# no nutrition_data ../rawdata/456993/3994392/
# no nutrition_data ../rawdata/443254/3980638/
# no nutrition_data ../rawdata/398483/3935804/
# no nutrition_data ../rawdata/513704/4051094/
# no nutrition_data ../rawdata/501767/4039163/
# no nutrition_data ../rawdata/59625/59964/
# no nutrition_data ../rawdata/398498/3935819/
# no nutrition_data ../rawdata/398486/3935807/
# no nutrition_data ../rawdata/57690/58029/
# no nutrition_data ../rawdata/59613/59952/
# no nutrition_data ../rawdata/484322/4021712/
# no nutrition_data ../rawdata/3040/3040/
# no nutrition_data ../rawdata/398495/3935816/
# no nutrition_data ../rawdata/55260/55599/
# no nutrition_data ../rawdata/398492/3935813/
# no nutrition_data ../rawdata/398489/3935810/
# no nutrition_data ../rawdata/715/715/
# no nutrition_data ../rawdata/398513/3935834/
# no nutrition_data ../rawdata/15997/16000/
# no nutrition_data ../rawdata/398501/3935822/
# no nutrition_data ../rawdata/398504/3935825/
# no nutrition_data ../rawdata/21133/21136/
# no nutrition_data ../rawdata/398507/3935828/
# no nutrition_data ../rawdata/20983/20986/
# no nutrition_data ../rawdata/67202/3604283/
# 6469
# row: 6472 already exists
# 19081
# row: 19084 already exists
# no nutrition_data ../rawdata/532895/4070285/
# no nutrition_data ../rawdata/76933/3614023/
# no nutrition_data ../rawdata/493038/4030440/
# no nutrition_data ../rawdata/76997/3614087/
# no nutrition_data ../rawdata/77001/3614091/
# no nutrition_data ../rawdata/77103/3614193/
# no nutrition_data ../rawdata/369232/3906511/
# no nutrition_data ../rawdata/424778/3962156/
# no nutrition_data ../rawdata/374215/3911494/
# no nutrition_data ../rawdata/78459/3615549/
# no nutrition_data ../rawdata/514578/4051968/
# no nutrition_data ../rawdata/369235/3906514/
# no nutrition_data ../rawdata/77031/3614121/
# no nutrition_data ../rawdata/368890/3906169/
# no nutrition_data ../rawdata/417342/3954711/
# no nutrition_data ../rawdata/368779/3906058/
# no nutrition_data ../rawdata/368773/3906052/
# no nutrition_data ../rawdata/414078/3951444/
# no nutrition_data ../rawdata/414075/3951441/
# no nutrition_data ../rawdata/525616/4063006/
# no nutrition_data ../rawdata/486245/4023632/
# 442825
# row: 3980209 already exists
# 442822
# row: 3980206 already exists
# 442828
# row: 3980212 already exists
# wrong format ../rawdata/36733/36736/
# 36739
# row: 36742 already exists
# 36736
# row: 36739 already exists
# 36742
# row: 36745 already exists
# wrong format ../rawdata/9040/9043/
# wrong format ../rawdata/17770/17773/
# wrong format ../rawdata/9043/9046/
# no nutrition_data ../rawdata/561411/4098801/
# ../rawdata/36328/36331/
# no nutrition_data ../rawdata/570240/4107630/
# 97491
# row: 3634551 already exists
# no nutrition_data ../rawdata/134891/3672104/
# 19606
# row: 19609 already exists
# no nutrition_data ../rawdata/403680/3941016/
# 545794
# row: 4083184 already exists
# no nutrition_data ../rawdata/561297/4098687/
# wrong format ../rawdata/451807/3989197/
# no nutrition_data ../rawdata/402909/3940245/
# 37381
# row: 37384 already exists
# no nutrition_data ../rawdata/135035/3672248/
# 37387
# row: 37390 already exists
# no nutrition_data ../rawdata/561354/4098744/
# 545779
# row: 4083169 already exists
# no nutrition_data ../rawdata/561258/4098648/
# 37384
# row: 37387 already exists
# no nutrition_data ../rawdata/257919/3795198/
# 37393
# row: 37396 already exists
# no nutrition_data ../rawdata/318284/3855575/
# 545800
# row: 4083190 already exists
# no nutrition_data ../rawdata/561390/4098780/
# 545791
# row: 4083181 already exists
# no nutrition_data ../rawdata/561396/4098786/
# 409826
# row: 3947189 already exists
# no nutrition_data ../rawdata/561120/4098510/
# 408078
# row: 3945429 already exists
# no nutrition_data ../rawdata/561393/4098783/
# 409832
# row: 3947195 already exists
# 97495
# row: 3634555 already exists
# 408081
# row: 3945432 already exists
# wrong format ../rawdata/545776/4083166/
# 43678
# row: 43681 already exists
# 43675
# row: 43678 already exists
# 502376
# row: 4039772 already exists
# 439228
# row: 3976612 already exists
# 545797
# row: 4083187 already exists
# 545803
# row: 4083193 already exists
# no nutrition_data ../rawdata/89987/3627077/
# no nutrition_data ../rawdata/257172/3794451/
# no nutrition_data ../rawdata/258402/3795681/
# no nutrition_data ../rawdata/134229/3671442/
# no nutrition_data ../rawdata/553902/4091292/
# no nutrition_data ../rawdata/555846/4093236/
# no nutrition_data ../rawdata/554958/4092348/
# no nutrition_data ../rawdata/92849/3629939/
# no nutrition_data ../rawdata/482834/4020224/
# no nutrition_data ../rawdata/555528/4092918/
# no nutrition_data ../rawdata/258330/3795609/
# no nutrition_data ../rawdata/70681/3607771/
# no nutrition_data ../rawdata/553968/4091358/
# no nutrition_data ../rawdata/400274/3937601/
# no nutrition_data ../rawdata/184790/3722033/
# no nutrition_data ../rawdata/185003/3722246/
# no nutrition_data ../rawdata/485950/4023343/
# no nutrition_data ../rawdata/72719/3609809/
# no nutrition_data ../rawdata/134067/3671280/
# no nutrition_data ../rawdata/541869/4079259/
# 537705
# row: 4075095 already exists
# 469037
# 469037
# 462931
# row: 4000321 already exists
# 506874
# row: 4044264 already exists
# 506868
# row: 4044258 already exists
# 468788
# 468788
# 533933
# row: 4071323 already exists
# 549279
# row: 4086669 already exists
# 50160
# row: 50496 already exists
# 182452
# row: 3719689 already exists
# 50268
# row: 50604 already exists
# 522940
# row: 4060330 already exists
# 557235
# row: 4094625 already exists
# 470867
# row: 4008239 already exists
# 439531
# row: 3976915 already exists
# 149188
# row: 3686434 already exists
# 394090
# row: 3931393 already exists
# 17749
# row: 17752 already exists
# 17755
# row: 17758 already exists
# 547505
# row: 4084895 already exists
# 502526
# row: 4039922 already exists
# 502523
# row: 4039919 already exists
# 500909
# row: 4038305 already exists
# 500906
# row: 4038302 already exists
# 522937
# row: 4060327 already exists
# 524245
# row: 4061635 already exists
# 123139
# row: 3660334 already exists
# 101457
# row: 3638664 already exists
# 101460
# row: 3638667 already exists
# 207496
# row: 3744745 already exists
# 452176
# row: 3989566 already exists
# 452173
# row: 3989563 already exists
# 581350
# row: 4118740 already exists
# 581356
# row: 4118746 already exists
# 581353
# row: 4118743 already exists
# 452152
# row: 3989542 already exists
# 50172
# row: 50508 already exists
# 50169
# row: 50505 already exists
# wrong format ../rawdata/30445/30448/
# 439528
# row: 3976912 already exists
# 30448
# row: 30451 already exists
# 67166
# row: 3604247 already exists
# 65063
# row: 3602144 already exists
# 96775
# row: 3633811 already exists
# 30430
# row: 30433 already exists
# 190294
# row: 3727540 already exists
# 190300
# row: 3727546 already exists
# 49638
# row: 49974 already exists
# 408243
# row: 3945594 already exists
# 50709
# row: 51048 already exists
# 49641
# row: 49977 already exists
# 190297
# row: 3727543 already exists
# 190309
# row: 3727555 already exists
# 190306
# row: 3727552 already exists
# 50265
# row: 50601 already exists
# 545680
# row: 4083070 already exists
# 473786
# row: 4011161 already exists
# 13903
# row: 13906 already exists
# 4663
# row: 4663 already exists
# 50712
# row: 51051 already exists
# 473597
# row: 4010972 already exists
# 49644
# row: 49980 already exists
# 49647
# row: 49983 already exists
# 50706
# row: 51045 already exists
# 97637
# row: 3634699 already exists
# 464938
# row: 4002328 already exists
# 97635
# row: 3634697 already exists
# 545677
# row: 4083067 already exists
# 458064
# row: 3995454 already exists
# 50556
# row: 50895 already exists
# ../rawdata/441604/3978988/
# 24220
# row: 24223 already exists
# 468386
# row: 4005758 already exists
# 50628
# row: 50967 already exists
# 411331
# row: 3948697 already exists
# 193475
# row: 3730718 already exists
# 193478
# row: 3730721 already exists
# 69425
# row: 3606506 already exists
# 131451
# row: 3668652 already exists
# 37060
# row: 37063 already exists
# 31285
# row: 31288 already exists
# 20518
# row: 20521 already exists
# 29620
# row: 29623 already exists
# 20521
# row: 20524 already exists
# 8800
# row: 8803 already exists
# 29617
# row: 29620 already exists
# 464941
# row: 4002331 already exists
# 546425
# row: 4083815 already exists
# 546428
# row: 4083818 already exists
# 503021
# row: 4040417 already exists
# 470864
# row: 4008236 already exists
# 100912
# row: 3638119 already exists
# 493897
# row: 4031305 already exists
# 553617
# row: 4091007 already exists
# 407784
# row: 3945135 already exists
# 25063
# row: 25066 already exists
# 122655
# row: 3659853 already exists
# 122652
# row: 3659850 already exists
# 50178
# row: 50514 already exists
# 103729
# row: 3640921 already exists
# 69422
# row: 3606503 already exists
# 103984
# row: 3641176 already exists
# 547136
# row: 4084526 already exists
# 547133
# row: 4084523 already exists
# no nutrition_data ../rawdata/543961/4081351/
# no nutrition_data ../rawdata/543958/4081348/
# no nutrition_data ../rawdata/543964/4081354/
# no nutrition_data ../rawdata/543967/4081357/
# no nutrition_data ../rawdata/552615/4090005/
# no nutrition_data ../rawdata/552618/4090008/
# no nutrition_data ../rawdata/552624/4090014/
# no nutrition_data ../rawdata/552609/4089999/
# no nutrition_data ../rawdata/552612/4090002/
# no nutrition_data ../rawdata/552621/4090011/
# 68972
# row: 3606053 already exists
# 68969
# row: 3606050 already exists
# 506460
# row: 4043850 already exists
# 463291
# 463291
# 5911
# row: 5914 already exists
# 5914
# row: 5917 already exists
# 53061
# row: 53400 already exists
# 32845
# row: 32848 already exists
# wrong format ../rawdata/30394/30397/
# wrong format ../rawdata/30397/30400/
# 440905
# row: 3978289 already exists
# 506463
# row: 4043853 already exists
# 44587
# row: 44590 already exists
# 68975
# row: 3606056 already exists
# 506364
# row: 4043754 already exists
# 457425
# row: 3994818 already exists
# 440923
# row: 3978307 already exists
# 32848
# row: 32851 already exists
# 68978
# row: 3606059 already exists
# 440806
# row: 3978190 already exists
# 440803
# row: 3978187 already exists
# 440800
# row: 3978184 already exists
# 296633
# row: 3833924 already exists
# 545404
# row: 4082794 already exists
# 68948
# row: 3606029 already exists
# 122406
# row: 3659604 already exists
# 68951
# row: 3606032 already exists
# 131634
# row: 3668838 already exists
# 131268
# row: 3668469 already exists
# 440812
# row: 3978196 already exists
# 68159
# row: 3605240 already exists
# 189811
# row: 3727057 already exists
# 442717
# row: 3980101 already exists
# 147673
# row: 3684919 already exists
# 493864
# row: 4031272 already exists
# 550260
# row: 4087650 already exists
# 99135
# row: 3636339 already exists
# 99138
# row: 3636342 already exists
# 550266
# row: 4087656 already exists
# 550269
# row: 4087659 already exists
# 255416
# row: 3792689 already exists
# 255407
# row: 3792680 already exists
# 501125
# row: 4038521 already exists
# 501122
# row: 4038518 already exists
# 19471
# row: 19474 already exists
# 145237
# row: 3682486 already exists
# 32002
# row: 32005 already exists
# 122766
# row: 3659961 already exists
# no nutrition_data ../rawdata/444736/3982120/
# 99561
# row: 3636765 already exists
# 9331
# row: 9334 already exists
# 16831
# row: 16834 already exists
# 22141
# row: 22144 already exists
# 17161
# row: 17164 already exists
# 192061
# row: 3729307 already exists
# 70383
# row: 3607473 already exists
# 70387
# row: 3607477 already exists
# 70377
# row: 3607467 already exists
# 70381
# row: 3607471 already exists
# 70379
# row: 3607469 already exists
# 149671
# row: 3686917 already exists
# 149668
# row: 3686914 already exists
# 70375
# row: 3607465 already exists
# 150796
# row: 3688042 already exists
# 24376
# row: 24379 already exists
# 43969
# row: 43972 already exists
# 43975
# row: 43978 already exists
# 70385
# row: 3607475 already exists
# 52986
# row: 53325 already exists
# 3751
# row: 3751 already exists
# 112495
# row: 3649690 already exists
# 425092
# row: 3962473 already exists
# 112492
# row: 3649687 already exists
# 543030
# row: 4080420 already exists
# 543033
# row: 4080423 already exists
# 1837
# row: 1837 already exists
# 62516
# row: 3599603 already exists
# 13504
# row: 13507 already exists
# 3403
# row: 3403 already exists
# 35887
# row: 35890 already exists
# 9856
# row: 9859 already exists
# 133
# row: 133 already exists
# 99552
# row: 3636756 already exists
# 99558
# row: 3636762 already exists
# 21169
# row: 21172 already exists
# 121279
# row: 3658474 already exists
# 20665
# row: 20668 already exists
# 3430
# row: 3430 already exists
# 25891
# row: 25894 already exists
# 122733
# row: 3659931 already exists
# 198225
# row: 3735468 already exists
# 198222
# row: 3735465 already exists
# 543150
# row: 4080540 already exists
# 408033
# row: 3945384 already exists
# 3589
# row: 3589 already exists
# 543114
# row: 4080504 already exists
# 500171
# row: 4037570 already exists
# 500174
# row: 4037573 already exists
# 560163
# row: 4097553 already exists
# 560160
# row: 4097550 already exists
# 560166
# row: 4097556 already exists
# ../rawdata/25726/25729/
# 72963
# row: 3610051 already exists
# 72957
# row: 3610045 already exists
# 72967
# row: 3610055 already exists
# 72961
# row: 3610049 already exists
# 3703
# row: 3703 already exists
# 1813
# row: 1813 already exists
# 500141
# row: 4037540 already exists
# 391602
# row: 3928887 already exists
# 391605
# row: 3928890 already exists
# ../rawdata/543093/4080483/
# 146012
# row: 3683258 already exists
# 506631
# row: 4044021 already exists
# 506634
# row: 4044024 already exists
# 507985
# row: 4045375 already exists
# 508000
# row: 4045390 already exists
# 443050
# row: 3980434 already exists
# 443053
# row: 3980437 already exists
# 67796
# row: 3604877 already exists
# 67793
# row: 3604874 already exists
# 53688
# row: 54027 already exists
# 48339
# row: 48651 already exists
# 97283
# row: 3634317 already exists
# 407805
# row: 3945156 already exists
# 407808
# row: 3945159 already exists
# 543219
# row: 4080609 already exists
# 543222
# row: 4080612 already exists
# 543216
# row: 4080606 already exists
# 543126
# row: 4080516 already exists
# 543129
# row: 4080519 already exists
# 543144
# row: 4080534 already exists
# 501140
# 501140
# 466144
# 466144
# 466156
# 466156
# 466147
# 466147
# 70389
# row: 3607479 already exists
# 255413
# row: 3792686 already exists
# 24382
# row: 24385 already exists
# 24379
# row: 24382 already exists
# 24391
# row: 24394 already exists
# 8986
# row: 8989 already exists
# 9052
# row: 9055 already exists
# 9055
# row: 9058 already exists
# 9058
# row: 9061 already exists
# 9064
# row: 9067 already exists
# 441403
# row: 3978787 already exists
# 12250
# row: 12253 already exists
# 9319
# row: 9322 already exists
# 12247
# row: 12250 already exists
# 443020
# row: 3980404 already exists
# 43972
# row: 43975 already exists
# 543108
# row: 4080498 already exists
# 502724
# row: 4040120 already exists
# 21172
# row: 21175 already exists
# 502721
# row: 4040117 already exists
# 3595
# row: 3595 already exists
# 502727
# row: 4040123 already exists
# 543228
# row: 4080618 already exists
# 425089
# row: 3962470 already exists
# 543111
# row: 4080501 already exists
# 25894
# row: 25897 already exists
# 407850
# row: 3945201 already exists
# 543099
# row: 4080489 already exists
# 543231
# row: 4080621 already exists
# 255410
# row: 3792683 already exists
# 41065
# row: 41068 already exists
# 31993
# row: 31996 already exists
# 2755
# row: 2755 already exists
# 39220
# row: 39223 already exists
# 14338
# row: 14341 already exists
# 99405
# row: 3636609 already exists
# 20017
# row: 20020 already exists
# 43981
# row: 43984 already exists
# 97293
# row: 3634327 already exists
# 2179
# row: 2179 already exists
# 25900
# row: 25903 already exists
# 13426
# row: 13429 already exists
# 3532
# row: 3532 already exists
# 1804
# row: 1804 already exists
# 20662
# row: 20665 already exists
# 13423
# row: 13426 already exists
# 13429
# row: 13432 already exists
# 130557
# row: 3667758 already exists
# 130560
# row: 3667761 already exists
# 408036
# row: 3945387 already exists
# 21181
# row: 21184 already exists
# 40783
# row: 40786 already exists
# 391599
# row: 3928884 already exists
# ../rawdata/543096/4080486/
# 407802
# row: 3945153 already exists
# 543225
# row: 4080615 already exists
# 255419
# row: 3792692 already exists
# 31990
# row: 31993 already exists
# 32005
# row: 32008 already exists
# 2758
# row: 2758 already exists
# 9313
# row: 9316 already exists
# 149122
# row: 3686368 already exists
# 150283
# row: 3687529 already exists
# 3457
# row: 3457 already exists
# 3604
# row: 3604 already exists
# 1810
# row: 1810 already exists
# 21184
# row: 21187 already exists
# 13510
# row: 13513 already exists
# no nutrition_data ../rawdata/211814/3749075/
# no nutrition_data ../rawdata/211793/3749054/
# no nutrition_data ../rawdata/211799/3749060/
# 24595
# row: 24598 already exists
# no nutrition_data ../rawdata/211805/3749066/
# 3655
# row: 3655 already exists
# no nutrition_data ../rawdata/211823/3749084/
# no nutrition_data ../rawdata/8551/8554/
# 440569
# row: 3977953 already exists
# 440578
# row: 3977962 already exists
# 440080
# row: 3977464 already exists
# no nutrition_data ../rawdata/1621/1621/
# 1792
# row: 1792 already exists
# 3652
# row: 3652 already exists
# no nutrition_data ../rawdata/442843/3980227/
# no nutrition_data ../rawdata/8548/8551/
# no nutrition_data ../rawdata/8536/8539/
# no nutrition_data ../rawdata/8545/8548/
# 9853
# row: 9856 already exists
# no nutrition_data ../rawdata/27289/27292/
# no nutrition_data ../rawdata/9325/9328/
# 440593
# row: 3977977 already exists
# 3778
# row: 3778 already exists
# no nutrition_data ../rawdata/424915/3962296/
# ../rawdata/424939/3962320/
# no nutrition_data ../rawdata/10141/10144/
# wrong format ../rawdata/440155/3977539/
# 21163
# row: 21166 already exists
# no nutrition_data ../rawdata/25747/25750/
# 3670
# row: 3670 already exists
# 3739
# row: 3739 already exists
# 3868
# row: 3868 already exists
# 3904
# row: 3904 already exists
# 3883
# row: 3883 already exists
# 3718
# row: 3718 already exists
# 192523
# row: 3729769 already exists
# 9085
# row: 9088 already exists
# 3880
# row: 3880 already exists
# 19468
# row: 19471 already exists
# 3646
# row: 3646 already exists
# 501584
# row: 4038980 already exists
# 186904
# row: 3724150 already exists
# 21244
# row: 21247 already exists
# 544162
# row: 4081552 already exists
# 544159
# row: 4081549 already exists
# 544990
# row: 4082380 already exists
# 544963
# row: 4082353 already exists
# wrong format ../rawdata/544192/4081582/
# 544993
# row: 4082383 already exists
# wrong format ../rawdata/544951/4082341/
# no nutrition_data ../rawdata/545230/4082620/
# 544981
# row: 4082371 already exists
# 544978
# row: 4082368 already exists
# 544984
# row: 4082374 already exists
# wrong format ../rawdata/544987/4082377/
# wrong format ../rawdata/524548/4061938/
# wrong format ../rawdata/544195/4081585/
# wrong format ../rawdata/544966/4082356/
# 498781
# row: 4036183 already exists
# 498808
# row: 4036210 already exists
# 191587
# row: 3728833 already exists
# 553680
# row: 4091070 already exists
# 553692
# row: 4091082 already exists
# 553656
# row: 4091046 already exists
# 553668
# row: 4091058 already exists
# 553659
# row: 4091049 already exists
# 553662
# row: 4091052 already exists
# 553665
# row: 4091055 already exists
# 553677
# row: 4091067 already exists
# 553650
# row: 4091040 already exists
# 553674
# row: 4091064 already exists
# 553686
# row: 4091076 already exists
# 553683
# row: 4091073 already exists
# 553671
# row: 4091061 already exists
# 553653
# row: 4091043 already exists
# 553689
# row: 4091079 already exists
# 101843
# row: 3639050 already exists
# 508669
# row: 4046059 already exists
# 501371
# row: 4038767 already exists
# ../rawdata/542622/4080012/
# 252970
# row: 3790237 already exists
# 542631
# row: 4080021 already exists
# 101762
# row: 3638969 already exists
# 543027
# row: 4080417 already exists
# 101846
# row: 3639053 already exists
# 542625
# row: 4080015 already exists
# 252973
# row: 3790240 already exists
# 542628
# row: 4080018 already exists
# 508663
# row: 4046053 already exists
# 500285
# row: 4037684 already exists
# 508666
# row: 4046056 already exists
# 500276
# row: 4037675 already exists
# 542652
# row: 4080042 already exists
# 410935
# row: 3948301 already exists
# 501362
# row: 4038758 already exists
# 501359
# row: 4038755 already exists
# 501368
# row: 4038764 already exists
# 557085
# row: 4094475 already exists
# 191566
# row: 3728812 already exists
# 191596
# row: 3728842 already exists
# 191584
# row: 3728830 already exists
# 191581
# row: 3728827 already exists
# 411328
# row: 3948694 already exists
# no nutrition_data ../rawdata/387261/3924537/
# no nutrition_data ../rawdata/64433/3601514/
# no nutrition_data ../rawdata/433433/3970808/
# no nutrition_data ../rawdata/64136/3601217/
# no nutrition_data ../rawdata/438367/3975754/
# no nutrition_data ../rawdata/387255/3924531/
# no nutrition_data ../rawdata/387258/3924534/
# no nutrition_data ../rawdata/64130/3601211/
# no nutrition_data ../rawdata/64133/3601214/
# no nutrition_data ../rawdata/64139/3601220/
# no nutrition_data ../rawdata/460954/3998338/
# no nutrition_data ../rawdata/438364/3975751/
# no nutrition_data ../rawdata/491746/4029145/
# no nutrition_data ../rawdata/94711/3631801/
# no nutrition_data ../rawdata/561363/4098753/
# no nutrition_data ../rawdata/561135/4098525/
# no nutrition_data ../rawdata/556821/4094211/
# no nutrition_data ../rawdata/525703/4063093/
# no nutrition_data ../rawdata/491515/4028914/
# no nutrition_data ../rawdata/525733/4063123/
# no nutrition_data ../rawdata/556917/4094307/
# no nutrition_data ../rawdata/448035/3985425/
# no nutrition_data ../rawdata/403668/3941004/
# no nutrition_data ../rawdata/556890/4094280/
# no nutrition_data ../rawdata/556923/4094313/
# no nutrition_data ../rawdata/403833/3941169/
# no nutrition_data ../rawdata/403935/3941271/
# no nutrition_data ../rawdata/403938/3941274/
# no nutrition_data ../rawdata/561408/4098798/
# no nutrition_data ../rawdata/561414/4098804/
# no nutrition_data ../rawdata/561420/4098810/
# no nutrition_data ../rawdata/561423/4098813/
# no nutrition_data ../rawdata/561426/4098816/
# no nutrition_data ../rawdata/561177/4098567/
# no nutrition_data ../rawdata/561225/4098615/
# no nutrition_data ../rawdata/561228/4098618/
# no nutrition_data ../rawdata/318440/3855731/
# no nutrition_data ../rawdata/318437/3855728/
# no nutrition_data ../rawdata/421809/3959181/
# no nutrition_data ../rawdata/421803/3959175/
# no nutrition_data ../rawdata/403836/3941172/
# no nutrition_data ../rawdata/403830/3941166/
# no nutrition_data ../rawdata/561417/4098807/
# no nutrition_data ../rawdata/402696/3940032/
# no nutrition_data ../rawdata/421800/3959172/
# no nutrition_data ../rawdata/402693/3940029/
# no nutrition_data ../rawdata/402687/3940023/
# no nutrition_data ../rawdata/90997/3628087/
# no nutrition_data ../rawdata/561222/4098612/
# no nutrition_data ../rawdata/561405/4098795/
# no nutrition_data ../rawdata/404064/3941400/
# no nutrition_data ../rawdata/258234/3795513/
# no nutrition_data ../rawdata/421779/3959151/
# no nutrition_data ../rawdata/94523/3631613/
# no nutrition_data ../rawdata/403626/3940962/
# no nutrition_data ../rawdata/561285/4098675/
# no nutrition_data ../rawdata/556671/4094061/
# no nutrition_data ../rawdata/556737/4094127/
# no nutrition_data ../rawdata/561300/4098690/
# no nutrition_data ../rawdata/561294/4098684/
# no nutrition_data ../rawdata/258219/3795498/
# no nutrition_data ../rawdata/258225/3795504/
# no nutrition_data ../rawdata/421734/3959106/
# no nutrition_data ../rawdata/258216/3795495/
# no nutrition_data ../rawdata/421788/3959160/
# no nutrition_data ../rawdata/421773/3959145/
# no nutrition_data ../rawdata/421785/3959157/
# no nutrition_data ../rawdata/421776/3959148/
# no nutrition_data ../rawdata/134888/3672101/
# no nutrition_data ../rawdata/421752/3959124/
# no nutrition_data ../rawdata/421740/3959112/
# no nutrition_data ../rawdata/561291/4098681/
# no nutrition_data ../rawdata/561306/4098696/
# no nutrition_data ../rawdata/491533/4028932/
# no nutrition_data ../rawdata/570237/4107627/
# no nutrition_data ../rawdata/561123/4098513/
# no nutrition_data ../rawdata/561282/4098672/
# no nutrition_data ../rawdata/556902/4094292/
# no nutrition_data ../rawdata/556689/4094079/
# no nutrition_data ../rawdata/556791/4094181/
# no nutrition_data ../rawdata/134894/3672107/
# no nutrition_data ../rawdata/421743/3959115/
# no nutrition_data ../rawdata/421755/3959127/
# no nutrition_data ../rawdata/421746/3959118/
# no nutrition_data ../rawdata/421749/3959121/
# no nutrition_data ../rawdata/561111/4098501/
# no nutrition_data ../rawdata/491530/4028929/
# no nutrition_data ../rawdata/491518/4028917/
# no nutrition_data ../rawdata/491521/4028920/
# no nutrition_data ../rawdata/92987/3630077/
# no nutrition_data ../rawdata/556686/4094076/
# no nutrition_data ../rawdata/556815/4094205/
# no nutrition_data ../rawdata/556746/4094136/
# no nutrition_data ../rawdata/570234/4107624/
# no nutrition_data ../rawdata/556692/4094082/
# no nutrition_data ../rawdata/421818/3959190/
# no nutrition_data ../rawdata/135032/3672245/
# no nutrition_data ../rawdata/92985/3630075/
# no nutrition_data ../rawdata/570213/4107603/
# no nutrition_data ../rawdata/491581/4028980/
# no nutrition_data ../rawdata/491776/4029175/
# no nutrition_data ../rawdata/257817/3795096/
# no nutrition_data ../rawdata/561255/4098645/
# no nutrition_data ../rawdata/305906/3843197/
# no nutrition_data ../rawdata/305903/3843194/
# no nutrition_data ../rawdata/491431/4028830/
# no nutrition_data ../rawdata/421821/3959193/
# no nutrition_data ../rawdata/421824/3959196/
# no nutrition_data ../rawdata/421827/3959199/
# no nutrition_data ../rawdata/491677/4029076/
# no nutrition_data ../rawdata/561216/4098606/
# no nutrition_data ../rawdata/561288/4098678/
# no nutrition_data ../rawdata/257901/3795180/
# no nutrition_data ../rawdata/257859/3795138/
# no nutrition_data ../rawdata/491428/4028827/
# no nutrition_data ../rawdata/491434/4028833/
# no nutrition_data ../rawdata/491425/4028824/
# no nutrition_data ../rawdata/556794/4094184/
# no nutrition_data ../rawdata/556797/4094187/
# no nutrition_data ../rawdata/556926/4094316/
# no nutrition_data ../rawdata/491728/4029127/
# no nutrition_data ../rawdata/556728/4094118/
# no nutrition_data ../rawdata/561138/4098528/
# no nutrition_data ../rawdata/19345/19348/
# no nutrition_data ../rawdata/556881/4094271/
# no nutrition_data ../rawdata/570210/4107600/
# no nutrition_data ../rawdata/90661/3627751/
# no nutrition_data ../rawdata/492055/4029454/
# no nutrition_data ../rawdata/556680/4094070/
# no nutrition_data ../rawdata/492016/4029415/
# no nutrition_data ../rawdata/402765/3940101/
# no nutrition_data ../rawdata/556899/4094289/
# no nutrition_data ../rawdata/526093/4063483/
# no nutrition_data ../rawdata/525130/4062520/
# no nutrition_data ../rawdata/556788/4094178/
# no nutrition_data ../rawdata/556743/4094133/
# no nutrition_data ../rawdata/556920/4094310/
# no nutrition_data ../rawdata/556893/4094283/
# no nutrition_data ../rawdata/432508/3969886/
# no nutrition_data ../rawdata/90007/3627097/
# no nutrition_data ../rawdata/90011/3627101/
# no nutrition_data ../rawdata/403404/3940740/
# no nutrition_data ../rawdata/402987/3940323/
# no nutrition_data ../rawdata/556755/4094145/
# no nutrition_data ../rawdata/91381/3628471/
# no nutrition_data ../rawdata/556749/4094139/
# no nutrition_data ../rawdata/556779/4094169/
# no nutrition_data ../rawdata/91965/3629055/
# no nutrition_data ../rawdata/561351/4098741/
# no nutrition_data ../rawdata/556752/4094142/
# no nutrition_data ../rawdata/403413/3940749/
# no nutrition_data ../rawdata/570183/4107573/
# no nutrition_data ../rawdata/403416/3940752/
# no nutrition_data ../rawdata/570177/4107567/
# no nutrition_data ../rawdata/556683/4094073/
# no nutrition_data ../rawdata/525292/4062682/
# no nutrition_data ../rawdata/570174/4107564/
# no nutrition_data ../rawdata/556767/4094157/
# no nutrition_data ../rawdata/258015/3795294/
# no nutrition_data ../rawdata/570285/4107675/
# no nutrition_data ../rawdata/561186/4098576/
# no nutrition_data ../rawdata/556761/4094151/
# no nutrition_data ../rawdata/403050/3940386/
# no nutrition_data ../rawdata/556812/4094202/
# no nutrition_data ../rawdata/525247/4062637/
# no nutrition_data ../rawdata/561366/4098756/
# no nutrition_data ../rawdata/137899/3675124/
# no nutrition_data ../rawdata/561336/4098726/
# no nutrition_data ../rawdata/95007/3632097/
# no nutrition_data ../rawdata/132173/3669377/
# no nutrition_data ../rawdata/494410/4031818/
# no nutrition_data ../rawdata/135014/3672227/
# no nutrition_data ../rawdata/134870/3672083/
# no nutrition_data ../rawdata/402843/3940179/
# no nutrition_data ../rawdata/134999/3672212/
# no nutrition_data ../rawdata/491968/4029367/
# no nutrition_data ../rawdata/561339/4098729/
# no nutrition_data ../rawdata/258165/3795444/
# no nutrition_data ../rawdata/137896/3675121/
# no nutrition_data ../rawdata/570180/4107570/
# no nutrition_data ../rawdata/135002/3672215/
# no nutrition_data ../rawdata/561192/4098582/
# no nutrition_data ../rawdata/258153/3795432/
# no nutrition_data ../rawdata/561180/4098570/
# no nutrition_data ../rawdata/258027/3795306/
# no nutrition_data ../rawdata/570282/4107672/
# no nutrition_data ../rawdata/137911/3675136/
# no nutrition_data ../rawdata/305945/3843236/
# no nutrition_data ../rawdata/556878/4094268/
# no nutrition_data ../rawdata/492371/4029770/
# no nutrition_data ../rawdata/556875/4094265/
# no nutrition_data ../rawdata/561333/4098723/
# no nutrition_data ../rawdata/257991/3795270/
# no nutrition_data ../rawdata/561195/4098585/
# no nutrition_data ../rawdata/561384/4098774/
# no nutrition_data ../rawdata/257973/3795252/
# no nutrition_data ../rawdata/403056/3940392/
# no nutrition_data ../rawdata/561327/4098717/
# no nutrition_data ../rawdata/257976/3795255/
# no nutrition_data ../rawdata/561198/4098588/
# no nutrition_data ../rawdata/561315/4098705/
# no nutrition_data ../rawdata/561183/4098573/
# no nutrition_data ../rawdata/561189/4098579/
# no nutrition_data ../rawdata/257979/3795258/
# no nutrition_data ../rawdata/561270/4098660/
# no nutrition_data ../rawdata/556758/4094148/
# no nutrition_data ../rawdata/135011/3672224/
# no nutrition_data ../rawdata/561267/4098657/
# no nutrition_data ../rawdata/561387/4098777/
# no nutrition_data ../rawdata/403194/3940530/
# no nutrition_data ../rawdata/403197/3940533/
# no nutrition_data ../rawdata/494368/4031776/
# no nutrition_data ../rawdata/258018/3795297/
# no nutrition_data ../rawdata/561360/4098750/
# no nutrition_data ../rawdata/81749/3618839/
# no nutrition_data ../rawdata/525250/4062640/
# no nutrition_data ../rawdata/134927/3672140/
# no nutrition_data ../rawdata/561342/4098732/
# no nutrition_data ../rawdata/134930/3672143/
# no nutrition_data ../rawdata/525298/4062688/
# no nutrition_data ../rawdata/134924/3672137/
# no nutrition_data ../rawdata/81753/3618843/
# no nutrition_data ../rawdata/561357/4098747/
# no nutrition_data ../rawdata/520957/4058347/
# no nutrition_data ../rawdata/556725/4094115/
# no nutrition_data ../rawdata/403116/3940452/
# no nutrition_data ../rawdata/525256/4062646/
# no nutrition_data ../rawdata/403119/3940455/
# no nutrition_data ../rawdata/556782/4094172/
# no nutrition_data ../rawdata/561237/4098627/
# no nutrition_data ../rawdata/561381/4098771/
# no nutrition_data ../rawdata/492383/4029782/
# no nutrition_data ../rawdata/556719/4094109/
# no nutrition_data ../rawdata/491920/4029319/
# no nutrition_data ../rawdata/556785/4094175/
# no nutrition_data ../rawdata/81755/3618845/
# no nutrition_data ../rawdata/556701/4094091/
# no nutrition_data ../rawdata/561159/4098549/
# no nutrition_data ../rawdata/403107/3940443/
# no nutrition_data ../rawdata/318293/3855584/
# no nutrition_data ../rawdata/259290/3796569/
# no nutrition_data ../rawdata/556677/4094067/
# no nutrition_data ../rawdata/491980/4029379/
# no nutrition_data ../rawdata/556713/4094103/
# no nutrition_data ../rawdata/258081/3795360/
# no nutrition_data ../rawdata/570312/4107702/
# no nutrition_data ../rawdata/258075/3795354/
# no nutrition_data ../rawdata/570315/4107705/
# no nutrition_data ../rawdata/561273/4098663/
# no nutrition_data ../rawdata/556776/4094166/
# no nutrition_data ../rawdata/520960/4058350/
# no nutrition_data ../rawdata/556896/4094286/
# no nutrition_data ../rawdata/491953/4029352/
# no nutrition_data ../rawdata/557325/4094715/
# no nutrition_data ../rawdata/491974/4029373/
# no nutrition_data ../rawdata/403365/3940701/
# no nutrition_data ../rawdata/491971/4029370/
# no nutrition_data ../rawdata/556845/4094235/
# no nutrition_data ../rawdata/258042/3795321/
# no nutrition_data ../rawdata/561345/4098735/
# no nutrition_data ../rawdata/258039/3795318/
# no nutrition_data ../rawdata/81639/3618729/
# no nutrition_data ../rawdata/81643/3618733/
# no nutrition_data ../rawdata/258108/3795387/
# no nutrition_data ../rawdata/403134/3940470/
# no nutrition_data ../rawdata/491944/4029343/
# no nutrition_data ../rawdata/491941/4029340/
# no nutrition_data ../rawdata/570273/4107663/
# no nutrition_data ../rawdata/403098/3940434/
# no nutrition_data ../rawdata/403101/3940437/
# no nutrition_data ../rawdata/95099/3632189/
# no nutrition_data ../rawdata/556578/4093968/
# no nutrition_data ../rawdata/561156/4098546/
# no nutrition_data ../rawdata/403188/3940524/
# no nutrition_data ../rawdata/90667/3627757/
# no nutrition_data ../rawdata/403164/3940500/
# no nutrition_data ../rawdata/570279/4107669/
# no nutrition_data ../rawdata/556584/4093974/
# no nutrition_data ../rawdata/520954/4058344/
# no nutrition_data ../rawdata/491947/4029346/
# no nutrition_data ../rawdata/491950/4029349/
# no nutrition_data ../rawdata/561165/4098555/
# no nutrition_data ../rawdata/561162/4098552/
# no nutrition_data ../rawdata/403191/3940527/
# no nutrition_data ../rawdata/556590/4093980/
# no nutrition_data ../rawdata/556587/4093977/
# no nutrition_data ../rawdata/561309/4098699/
# no nutrition_data ../rawdata/556581/4093971/
# no nutrition_data ../rawdata/403113/3940449/
# no nutrition_data ../rawdata/258066/3795345/
# no nutrition_data ../rawdata/561168/4098558/
# no nutrition_data ../rawdata/134822/3672035/
# no nutrition_data ../rawdata/403182/3940518/
# no nutrition_data ../rawdata/556596/4093986/
# no nutrition_data ../rawdata/258069/3795348/
# no nutrition_data ../rawdata/492395/4029794/
# no nutrition_data ../rawdata/570270/4107660/
# no nutrition_data ../rawdata/561174/4098564/
# no nutrition_data ../rawdata/561171/4098561/
# no nutrition_data ../rawdata/556593/4093983/
# no nutrition_data ../rawdata/134882/3672095/
# no nutrition_data ../rawdata/258201/3795480/
# no nutrition_data ../rawdata/492377/4029776/
# no nutrition_data ../rawdata/95089/3632179/
# no nutrition_data ../rawdata/556617/4094007/
# no nutrition_data ../rawdata/81765/3618855/
# no nutrition_data ../rawdata/561147/4098537/
# no nutrition_data ../rawdata/520972/4058362/
# no nutrition_data ../rawdata/556611/4094001/
# no nutrition_data ../rawdata/556599/4093989/
# no nutrition_data ../rawdata/520975/4058365/
# no nutrition_data ../rawdata/258132/3795411/
# no nutrition_data ../rawdata/259446/3796725/
# no nutrition_data ../rawdata/561201/4098591/
# no nutrition_data ../rawdata/570231/4107621/
# no nutrition_data ../rawdata/561150/4098540/
# no nutrition_data ../rawdata/557331/4094721/
# no nutrition_data ../rawdata/557328/4094718/
# no nutrition_data ../rawdata/556620/4094010/
# no nutrition_data ../rawdata/561153/4098543/
# no nutrition_data ../rawdata/525499/4062889/
# no nutrition_data ../rawdata/525502/4062892/
# no nutrition_data ../rawdata/446173/3983551/
# no nutrition_data ../rawdata/446176/3983554/
# no nutrition_data ../rawdata/93627/3630717/
# no nutrition_data ../rawdata/93629/3630719/
# no nutrition_data ../rawdata/93631/3630721/
# 16918
# row: 16921 already exists
# 31870
# row: 31873 already exists
# 10168
# row: 10171 already exists
# 122151
# row: 3659349 already exists
# 51549
# row: 51891 already exists
# 26143
# row: 26146 already exists
# 497721
# row: 4035123 already exists
# 497751
# row: 4035153 already exists
# 497739
# row: 4035141 already exists
# 497742
# row: 4035144 already exists
# 497718
# row: 4035120 already exists
# 184400
# row: 3721646 already exists
# 14104
# row: 14107 already exists
# 52443
# row: 52782 already exists
# 500297
# row: 4037696 already exists
# 561474
# row: 4098864 already exists
# 552489
# row: 4089879 already exists
# 31867
# row: 31870 already exists
# 497733
# row: 4035135 already exists
# 34813
# row: 34816 already exists
# 122157
# row: 3659355 already exists
# 122148
# row: 3659346 already exists
# 208033
# row: 3745282 already exists
# 18352
# row: 18355 already exists
# 122145
# row: 3659343 already exists
# 497748
# row: 4035150 already exists
# 497754
# row: 4035156 already exists
# 497736
# row: 4035138 already exists
# 497715
# row: 4035117 already exists
# 52578
# row: 52917 already exists
# 497745
# row: 4035147 already exists
# 122037
# row: 3659235 already exists
# 122040
# row: 3659238 already exists
# 581551
# row: 4118941 already exists
# 500294
# row: 4037693 already exists
# 8140
# row: 8143 already exists
# 7897
# row: 7900 already exists
# 14575
# row: 14578 already exists
# 7900
# row: 7903 already exists
# 5482
# row: 5485 already exists
# 51501
# row: 51843 already exists
# 550689
# row: 4088079 already exists
# 17659
# row: 17662 already exists
# 51198
# row: 51540 already exists
# 12643
# row: 12646 already exists
# 207877
# row: 3745126 already exists
# 26149
# row: 26152 already exists
# 497712
# row: 4035114 already exists
# 52575
# row: 52914 already exists
# 497706
# row: 4035108 already exists
# 184589
# row: 3721835 already exists
# 208027
# row: 3745276 already exists
# 17656
# row: 17659 already exists
# 207883
# row: 3745132 already exists
# 207928
# row: 3745177 already exists
# 208045
# row: 3745294 already exists
# 12640
# row: 12643 already exists
# 207874
# row: 3745123 already exists
# 207880
# row: 3745129 already exists
# 24859
# row: 24862 already exists
# 208021
# row: 3745270 already exists
# 207925
# row: 3745174 already exists
# 34858
# row: 34861 already exists
# 435457
# row: 3972838 already exists
# 208024
# row: 3745273 already exists
# no nutrition_data ../rawdata/34816/34819/
# 532249
# row: 4069639 already exists
# no nutrition_data ../rawdata/34819/34822/
# ../rawdata/400670/3937997/
# 51600
# row: 51942 already exists
# 7768
# row: 7771 already exists
# 259
# row: 259 already exists
# 7771
# row: 7774 already exists
# 3130
# row: 3130 already exists
# 9490
# row: 9493 already exists
# 265
# row: 265 already exists
# 262
# row: 262 already exists
# 52185
# row: 52524 already exists
# 51510
# row: 51852 already exists
# 500342
# row: 4037741 already exists
# 500348
# row: 4037747 already exists
# 500354
# row: 4037753 already exists
# 500357
# row: 4037756 already exists
# 500351
# row: 4037750 already exists
# 7714
# row: 7717 already exists
# 184409
# row: 3721655 already exists
# 16420
# row: 16423 already exists
# 7705
# row: 7708 already exists
# 184412
# row: 3721658 already exists
# 7717
# row: 7720 already exists
# wrong format ../rawdata/103007/3640205/
# 208015
# row: 3745264 already exists
# 208012
# row: 3745261 already exists
# 53124
# row: 53463 already exists
# 53127
# row: 53466 already exists
# 14578
# row: 14581 already exists
# 1960
# row: 1960 already exists
# 15316
# row: 15319 already exists
# 17995
# row: 17998 already exists
# 103004
# row: 3640202 already exists
# 513368
# row: 4050758 already exists
# 400727
# row: 3938054 already exists
# 552399
# row: 4089789 already exists
# 6106
# row: 6109 already exists
# 22813
# row: 22816 already exists
# 26146
# row: 26149 already exists
# 22816
# row: 22819 already exists
# 22819
# row: 22822 already exists
# 14560
# row: 14563 already exists
# 497703
# row: 4035105 already exists
# 435124
# row: 3972505 already exists
# 18415
# row: 18418 already exists
# 435139
# row: 3972520 already exists
# 295055
# row: 3832346 already exists
# 497694
# row: 4035096 already exists
# 435121
# row: 3972502 already exists
# 497697
# row: 4035099 already exists
# 435130
# row: 3972511 already exists
# 435133
# row: 3972514 already exists
# ../rawdata/497700/4035102/
# 435127
# row: 3972508 already exists
# 497691
# row: 4035093 already exists
# ../rawdata/435118/3972499/
# 435136
# row: 3972517 already exists
# 435058
# row: 3972439 already exists
# 122163
# row: 3659361 already exists
# 435145
# row: 3972526 already exists
# 1519
# row: 1519 already exists
# 5125
# row: 5128 already exists
# 513746
# row: 4051136 already exists
# 15400
# row: 15403 already exists
# 35101
# row: 35104 already exists
# 17818
# row: 17821 already exists
# 27565
# row: 27568 already exists
# 27574
# row: 27577 already exists
# 10261
# row: 10264 already exists
# 17830
# row: 17833 already exists
# 346
# row: 346 already exists
# 16756
# row: 16759 already exists
# 29713
# row: 29716 already exists
# 9487
# row: 9490 already exists
# 17401
# row: 17404 already exists
# 5164
# row: 5167 already exists
# 6328
# row: 6331 already exists
# 434929
# row: 3972310 already exists
# 183081
# row: 3720318 already exists
# 400694
# row: 3938021 already exists
# 400691
# row: 3938018 already exists
# 208108
# row: 3745357 already exists
# 17596
# row: 17599 already exists
# 202
# row: 202 already exists
# 17515
# row: 17518 already exists
# 7711
# row: 7714 already exists
# 45109
# row: 45112 already exists
# 1894
# row: 1894 already exists
# 35104
# row: 35107 already exists
# 7576
# row: 7579 already exists
# 45112
# row: 45115 already exists
# 10255
# row: 10258 already exists
# 1897
# row: 1897 already exists
# 3139
# row: 3139 already exists
# 244
# row: 244 already exists
# 253
# row: 253 already exists
# 256
# row: 256 already exists
# 3121
# row: 3121 already exists
# 3124
# row: 3124 already exists
# 247
# row: 247 already exists
# 3127
# row: 3127 already exists
# 500339
# row: 4037738 already exists
# 506406
# row: 4043796 already exists
# 14113
# row: 14116 already exists
# 184478
# row: 3721724 already exists
# 184484
# row: 3721730 already exists
# 184487
# row: 3721733 already exists
# 14101
# row: 14104 already exists
# 9481
# row: 9484 already exists
# 29707
# row: 29710 already exists
# 497757
# row: 4035159 already exists
# 497760
# row: 4035162 already exists
# 497763
# row: 4035165 already exists
# 497766
# row: 4035168 already exists
# 207796
# row: 3745045 already exists
# 16825
# row: 16828 already exists
# 14119
# row: 14122 already exists
# 14122
# row: 14125 already exists
# 184469
# row: 3721715 already exists
# 184460
# row: 3721706 already exists
# 184463
# row: 3721709 already exists
# 208000
# row: 3745249 already exists
# 506796
# row: 4044186 already exists
# 70253
# row: 3607341 already exists
# 70257
# row: 3607345 already exists
# 400748
# row: 3938075 already exists
# 400679
# row: 3938006 already exists
# 400763
# row: 3938090 already exists
# 103346
# row: 3640544 already exists
# 400754
# row: 3938081 already exists
# 400757
# row: 3938084 already exists
# 103337
# row: 3640535 already exists
# 103328
# row: 3640526 already exists
# 400703
# row: 3938030 already exists
# 103334
# row: 3640532 already exists
# 400760
# row: 3938087 already exists
# wrong format ../rawdata/25675/25678/
# 25678
# row: 25681 already exists
# 25681
# row: 25684 already exists
# 17641
# row: 17644 already exists
# 7708
# row: 7711 already exists
# 21487
# row: 21490 already exists
# 17647
# row: 17650 already exists
# 17725
# row: 17728 already exists
# 21478
# row: 21481 already exists
# 21799
# row: 21802 already exists
# 21493
# row: 21496 already exists
# 21496
# row: 21499 already exists
# 21499
# row: 21502 already exists
# 3142
# row: 3142 already exists
# 7732
# row: 7735 already exists
# 3886
# row: 3886 already exists
# 14128
# row: 14131 already exists
# 10885
# row: 10888 already exists
# 10891
# row: 10894 already exists
# 10888
# row: 10891 already exists
# 532027
# row: 4069417 already exists
# 400730
# row: 3938057 already exists
# wrong format ../rawdata/208090/3745339/
# wrong format ../rawdata/208096/3745345/
# 208087
# row: 3745336 already exists
# 500288
# row: 4037687 already exists
# 506943
# row: 4044333 already exists
# wrong format ../rawdata/435109/3972490/
# 7315
# row: 7318 already exists
# 27637
# row: 27640 already exists
# 34855
# row: 34858 already exists
# 4828
# row: 4828 already exists
# 5986
# row: 5989 already exists
# 400925
# row: 3938255 already exists
# 4831
# row: 4831 already exists
# 5980
# row: 5983 already exists
# 103322
# row: 3640520 already exists
# 506946
# row: 4044336 already exists
# 4102
# row: 4102 already exists
# 4105
# row: 4105 already exists
# 45118
# row: 45121 already exists
# 27571
# row: 27574 already exists
# 45214
# row: 45217 already exists
# 6406
# row: 6409 already exists
# 45124
# row: 45127 already exists
# 6391
# row: 6394 already exists
# 10258
# row: 10261 already exists
# 10294
# row: 10297 already exists
# 1579
# row: 1579 already exists
# 207802
# row: 3745051 already exists
# 45127
# row: 45130 already exists
# 45130
# row: 45133 already exists
# 103349
# row: 3640547 already exists
# 45217
# row: 45220 already exists
# 103352
# row: 3640550 already exists
# 15403
# row: 15406 already exists
# 29710
# row: 29713 already exists
# 45211
# row: 45214 already exists
# 21475
# row: 21478 already exists
# 45121
# row: 45124 already exists
# 21481
# row: 21484 already exists
# 232
# row: 232 already exists
# 400685
# row: 3938012 already exists
# 238
# row: 238 already exists
# 229
# row: 229 already exists
# 217
# row: 217 already exists
# 5155
# row: 5158 already exists
# 241
# row: 241 already exists
# 211
# row: 211 already exists
# 5230
# row: 5233 already exists
# 208
# row: 208 already exists
# 6334
# row: 6337 already exists
# 9484
# row: 9487 already exists
# 552396
# row: 4089786 already exists
# 8788
# row: 8791 already exists
# 500390
# row: 4037789 already exists
# 27562
# row: 27565 already exists
# 17824
# row: 17827 already exists
# 8785
# row: 8788 already exists
# 27568
# row: 27571 already exists
# 16942
# row: 16945 already exists
# 17827
# row: 17830 already exists
# 17821
# row: 17824 already exists
# 17812
# row: 17815 already exists
# 223
# row: 223 already exists
# 9493
# row: 9496 already exists
# 220
# row: 220 already exists
# 5161
# row: 5164 already exists
# 103364
# row: 3640562 already exists
# 506949
# row: 4044339 already exists
# 103361
# row: 3640559 already exists
# 14125
# row: 14128 already exists
# 847
# ...
# no nutrition_data ../rawdata/536165/4073555/
# no nutrition_data ../rawdata/90103/3627193/
# no nutrition_data ../rawdata/536171/4073561/
# no nutrition_data ../rawdata/498208/4035613/
# no nutrition_data ../rawdata/491638/4029037/
# no nutrition_data ../rawdata/382183/3919459/
# no nutrition_data ../rawdata/553809/4091199/
# no nutrition_data ../rawdata/187391/3724637/
# no nutrition_data ../rawdata/379864/3917140/
# no nutrition_data ../rawdata/187592/3724838/
# no nutrition_data ../rawdata/90423/3627513/
# no nutrition_data ../rawdata/491653/4029052/
# no nutrition_data ../rawdata/382144/3919420/
# no nutrition_data ../rawdata/531046/4068436/
# no nutrition_data ../rawdata/187412/3724658/
# no nutrition_data ../rawdata/90099/3627189/
# no nutrition_data ../rawdata/90445/3627535/
# no nutrition_data ../rawdata/498106/4035511/
# no nutrition_data ../rawdata/491644/4029043/
# no nutrition_data ../rawdata/382153/3919429/
# no nutrition_data ../rawdata/382165/3919441/
# no nutrition_data ../rawdata/187418/3724664/
# no nutrition_data ../rawdata/90107/3627197/
# no nutrition_data ../rawdata/187424/3724670/
# no nutrition_data ../rawdata/498109/4035514/
# no nutrition_data ../rawdata/491647/4029046/
# no nutrition_data ../rawdata/552027/4089417/
# no nutrition_data ../rawdata/552033/4089423/
# no nutrition_data ../rawdata/187397/3724643/
# no nutrition_data ../rawdata/90105/3627195/
# no nutrition_data ../rawdata/187595/3724841/
# no nutrition_data ../rawdata/498271/4035676/
# no nutrition_data ../rawdata/305921/3843212/
# no nutrition_data ../rawdata/382156/3919432/
# no nutrition_data ../rawdata/382168/3919444/
# no nutrition_data ../rawdata/90447/3627537/
# no nutrition_data ../rawdata/88897/3625987/
# no nutrition_data ../rawdata/187598/3724844/
# no nutrition_data ../rawdata/498280/4035682/
# no nutrition_data ../rawdata/491656/4029055/
# no nutrition_data ../rawdata/382189/3919465/
# no nutrition_data ../rawdata/552030/4089420/
# no nutrition_data ../rawdata/187604/3724850/
# no nutrition_data ../rawdata/553797/4091187/
# no nutrition_data ../rawdata/187421/3724667/
# no nutrition_data ../rawdata/498220/4035625/
# no nutrition_data ../rawdata/491650/4029049/
# no nutrition_data ../rawdata/552036/4089426/
# no nutrition_data ../rawdata/553812/4091202/
# no nutrition_data ../rawdata/187607/3724853/
# no nutrition_data ../rawdata/420933/3958305/
# no nutrition_data ../rawdata/187613/3724859/
# no nutrition_data ../rawdata/495470/4032875/
# no nutrition_data ../rawdata/89909/3626999/
# no nutrition_data ../rawdata/517540/4054930/
# no nutrition_data ../rawdata/382147/3919423/
# no nutrition_data ../rawdata/187601/3724847/
# no nutrition_data ../rawdata/93291/3630381/
# no nutrition_data ../rawdata/187610/3724856/
# no nutrition_data ../rawdata/495494/4032899/
# no nutrition_data ../rawdata/89907/3626997/
# no nutrition_data ../rawdata/517555/4054945/
# no nutrition_data ../rawdata/382171/3919447/
# no nutrition_data ../rawdata/187616/3724862/
# no nutrition_data ../rawdata/90655/3627745/
# no nutrition_data ../rawdata/88729/3625819/
# no nutrition_data ../rawdata/498232/4035637/
# no nutrition_data ../rawdata/90831/3627921/
# no nutrition_data ../rawdata/91635/3628725/
# no nutrition_data ../rawdata/579504/4116894/
# no nutrition_data ../rawdata/514410/4051800/
# no nutrition_data ../rawdata/495449/4032857/
# no nutrition_data ../rawdata/498190/4035595/
# no nutrition_data ../rawdata/187385/3724631/
# no nutrition_data ../rawdata/498127/4035532/
# no nutrition_data ../rawdata/419829/3957201/
# no nutrition_data ../rawdata/90899/3627989/
# no nutrition_data ../rawdata/90911/3628001/
# no nutrition_data ../rawdata/582919/4120309/
# no nutrition_data ../rawdata/495458/4032866/
# no nutrition_data ../rawdata/491659/4029058/
# no nutrition_data ../rawdata/579507/4116897/
# no nutrition_data ../rawdata/498196/4035601/
# no nutrition_data ../rawdata/455682/3993081/
# no nutrition_data ../rawdata/379852/3917128/
# no nutrition_data ../rawdata/187409/3724655/
# no nutrition_data ../rawdata/498184/4035589/
# no nutrition_data ../rawdata/498142/4035547/
# no nutrition_data ../rawdata/498223/4035628/
# no nutrition_data ../rawdata/553800/4091190/
# no nutrition_data ../rawdata/582922/4120312/
# no nutrition_data ../rawdata/498112/4035517/
# no nutrition_data ../rawdata/491662/4029061/
# no nutrition_data ../rawdata/382744/3920020/
# no nutrition_data ../rawdata/498199/4035604/
# no nutrition_data ../rawdata/90441/3627531/
# no nutrition_data ../rawdata/90913/3628003/
# no nutrition_data ../rawdata/582988/4120378/
# no nutrition_data ../rawdata/91615/3628705/
# no nutrition_data ../rawdata/187394/3724640/
# no nutrition_data ../rawdata/498118/4035523/
# no nutrition_data ../rawdata/305933/3843224/
# no nutrition_data ../rawdata/517534/4054924/
# no nutrition_data ../rawdata/187379/3724625/
# no nutrition_data ../rawdata/498136/4035541/
# no nutrition_data ../rawdata/498133/4035538/
# no nutrition_data ../rawdata/553803/4091193/
# no nutrition_data ../rawdata/187406/3724652/
# no nutrition_data ../rawdata/498115/4035520/
# no nutrition_data ../rawdata/305942/3843233/
# no nutrition_data ../rawdata/90823/3627913/
# no nutrition_data ../rawdata/517537/4054927/
# no nutrition_data ../rawdata/582991/4120381/
# no nutrition_data ../rawdata/495479/4032884/
# no nutrition_data ../rawdata/498283/4035685/
# no nutrition_data ../rawdata/498139/4035544/
# no nutrition_data ../rawdata/420228/3957600/
# no nutrition_data ../rawdata/379855/3917131/
# no nutrition_data ../rawdata/582925/4120315/
# no nutrition_data ../rawdata/504536/4041938/
# no nutrition_data ../rawdata/383244/3920520/
# no nutrition_data ../rawdata/91451/3628541/
# no nutrition_data ../rawdata/382738/3920014/
# no nutrition_data ../rawdata/582916/4120306/
# no nutrition_data ../rawdata/498247/4035652/
# no nutrition_data ../rawdata/90113/3627203/
# no nutrition_data ../rawdata/504500/4041902/
# no nutrition_data ../rawdata/90425/3627515/
# no nutrition_data ../rawdata/383047/3920323/
# no nutrition_data ../rawdata/91129/3628219/
# no nutrition_data ../rawdata/394954/3932257/
# no nutrition_data ../rawdata/91445/3628535/
# no nutrition_data ../rawdata/504212/4041614/
# no nutrition_data ../rawdata/498244/4035649/
# no nutrition_data ../rawdata/504539/4041941/
# no nutrition_data ../rawdata/504506/4041908/
# no nutrition_data ../rawdata/93669/3630759/
# no nutrition_data ../rawdata/91455/3628545/
# no nutrition_data ../rawdata/90907/3627997/
# no nutrition_data ../rawdata/96079/3633169/
# no nutrition_data ../rawdata/504215/4041617/
# no nutrition_data ../rawdata/310496/3847787/
# no nutrition_data ../rawdata/495434/4032842/
# no nutrition_data ../rawdata/90909/3627999/
# no nutrition_data ../rawdata/504503/4041905/
# no nutrition_data ../rawdata/498265/4035670/
# no nutrition_data ../rawdata/579513/4116903/
# no nutrition_data ../rawdata/498205/4035610/
# no nutrition_data ../rawdata/395008/3932311/
# no nutrition_data ../rawdata/504218/4041620/
# no nutrition_data ../rawdata/504221/4041623/
# no nutrition_data ../rawdata/491629/4029028/
# no nutrition_data ../rawdata/495473/4032878/
# no nutrition_data ../rawdata/504545/4041947/
# no nutrition_data ../rawdata/504764/4042163/
# no nutrition_data ../rawdata/420138/3957510/
# no nutrition_data ../rawdata/90435/3627525/
# no nutrition_data ../rawdata/394990/3932293/
# no nutrition_data ../rawdata/420141/3957513/
# no nutrition_data ../rawdata/491641/4029040/
# no nutrition_data ../rawdata/498154/4035559/
# no nutrition_data ../rawdata/498124/4035529/
# no nutrition_data ../rawdata/498229/4035634/
# no nutrition_data ../rawdata/420123/3957495/
# no nutrition_data ../rawdata/495446/4032854/
# no nutrition_data ../rawdata/394996/3932299/
# no nutrition_data ../rawdata/395032/3932335/
# no nutrition_data ../rawdata/305930/3843221/
# no nutrition_data ../rawdata/90201/3627291/
# no nutrition_data ../rawdata/90703/3627793/
# no nutrition_data ../rawdata/498148/4035553/
# no nutrition_data ../rawdata/452659/3990049/
# no nutrition_data ../rawdata/395005/3932308/
# no nutrition_data ../rawdata/395029/3932332/
# no nutrition_data ../rawdata/305936/3843227/
# no nutrition_data ../rawdata/495440/4032848/
# no nutrition_data ../rawdata/504551/4041953/
# no nutrition_data ../rawdata/498193/4035598/
# no nutrition_data ../rawdata/552072/4089462/
# no nutrition_data ../rawdata/395011/3932314/
# no nutrition_data ../rawdata/395002/3932305/
# no nutrition_data ../rawdata/305939/3843230/
# no nutrition_data ../rawdata/495476/4032881/
# no nutrition_data ../rawdata/498268/4035673/
# no nutrition_data ../rawdata/90895/3627985/
# no nutrition_data ../rawdata/498277/4035679/
# no nutrition_data ../rawdata/378487/3915763/
# no nutrition_data ../rawdata/394960/3932263/
# no nutrition_data ../rawdata/498259/4035664/
# no nutrition_data ../rawdata/89371/3626461/
# no nutrition_data ../rawdata/498235/4035640/
# no nutrition_data ../rawdata/504527/4041929/
# no nutrition_data ../rawdata/394957/3932260/
# no nutrition_data ../rawdata/96033/3633123/
# no nutrition_data ../rawdata/90901/3627991/
# no nutrition_data ../rawdata/93785/3630875/
# no nutrition_data ../rawdata/92651/3629741/
# no nutrition_data ../rawdata/495467/4032872/
# no nutrition_data ../rawdata/96041/3633131/
# no nutrition_data ../rawdata/394972/3932275/
# no nutrition_data ../rawdata/90777/3627867/
# no nutrition_data ../rawdata/485132/4022525/
# no nutrition_data ../rawdata/498151/4035556/
# no nutrition_data ../rawdata/504512/4041914/
# no nutrition_data ../rawdata/394969/3932272/
# no nutrition_data ../rawdata/378508/3915784/
# no nutrition_data ../rawdata/498250/4035655/
# no nutrition_data ../rawdata/505366/4042765/
# no nutrition_data ../rawdata/88479/3625569/
# no nutrition_data ../rawdata/91131/3628221/
# no nutrition_data ../rawdata/394993/3932296/
# no nutrition_data ../rawdata/96035/3633125/
# no nutrition_data ../rawdata/498262/4035667/
# no nutrition_data ../rawdata/89977/3627067/
# no nutrition_data ../rawdata/90429/3627519/
# no nutrition_data ../rawdata/552060/4089450/
# no nutrition_data ../rawdata/394978/3932281/
# no nutrition_data ../rawdata/394981/3932284/
# no nutrition_data ../rawdata/90681/3627771/
# no nutrition_data ../rawdata/450198/3987588/
# no nutrition_data ../rawdata/498238/4035643/
# no nutrition_data ../rawdata/88935/3626025/
# no nutrition_data ../rawdata/395017/3932320/
# no nutrition_data ../rawdata/378496/3915772/
# no nutrition_data ../rawdata/90893/3627983/
# no nutrition_data ../rawdata/89373/3626463/
# no nutrition_data ../rawdata/91329/3628419/
# no nutrition_data ../rawdata/495461/4032869/
# no nutrition_data ../rawdata/498163/4035568/
# no nutrition_data ../rawdata/495443/4032851/
# no nutrition_data ../rawdata/455919/3993318/
# no nutrition_data ../rawdata/90431/3627521/
# no nutrition_data ../rawdata/505084/4042486/
# no nutrition_data ../rawdata/92547/3629637/
# no nutrition_data ../rawdata/498202/4035607/
# no nutrition_data ../rawdata/495452/4032860/
# no nutrition_data ../rawdata/89981/3627071/
# no nutrition_data ../rawdata/504542/4041944/
# no nutrition_data ../rawdata/92549/3629639/
# no nutrition_data ../rawdata/498160/4035565/
# no nutrition_data ../rawdata/89369/3626459/
# no nutrition_data ../rawdata/487228/4024618/
# no nutrition_data ../rawdata/90707/3627797/
# no nutrition_data ../rawdata/90773/3627863/
# no nutrition_data ../rawdata/424454/3961829/
# no nutrition_data ../rawdata/498130/4035535/
# no nutrition_data ../rawdata/303290/3840581/
# no nutrition_data ../rawdata/495455/4032863/
# no nutrition_data ../rawdata/498166/4035571/
# no nutrition_data ../rawdata/498253/4035658/
# no nutrition_data ../rawdata/485129/4022522/
# no nutrition_data ../rawdata/504485/4041887/
# no nutrition_data ../rawdata/504524/4041926/
# no nutrition_data ../rawdata/498172/4035577/
# no nutrition_data ../rawdata/91727/3628817/
# no nutrition_data ../rawdata/90701/3627791/
# no nutrition_data ../rawdata/89979/3627069/
# no nutrition_data ../rawdata/450860/3988250/
# no nutrition_data ../rawdata/90199/3627289/
# no nutrition_data ../rawdata/498157/4035562/
# no nutrition_data ../rawdata/498121/4035526/
# no nutrition_data ../rawdata/504488/4041890/
# no nutrition_data ../rawdata/498175/4035580/
# no nutrition_data ../rawdata/457014/3994413/
# no nutrition_data ../rawdata/91319/3628409/
# no nutrition_data ../rawdata/498241/4035646/
# no nutrition_data ../rawdata/498178/4035583/
# no nutrition_data ../rawdata/436830/3974214/
# no nutrition_data ../rawdata/582184/4119574/
# no nutrition_data ../rawdata/517942/4055332/
# no nutrition_data ../rawdata/419514/3956886/
# no nutrition_data ../rawdata/498256/4035661/
# no nutrition_data ../rawdata/450800/3988187/
# no nutrition_data ../rawdata/418836/3956208/
# no nutrition_data ../rawdata/552069/4089459/
# no nutrition_data ../rawdata/504497/4041899/
# no nutrition_data ../rawdata/498181/4035586/
# no nutrition_data ../rawdata/478450/4015837/
# no nutrition_data ../rawdata/90775/3627865/
# no nutrition_data ../rawdata/96073/3633163/
# no nutrition_data ../rawdata/375652/3912931/
# no nutrition_data ../rawdata/375655/3912934/
# no nutrition_data ../rawdata/375658/3912937/
# no nutrition_data ../rawdata/375709/3912988/
# no nutrition_data ../rawdata/375661/3912940/
# no nutrition_data ../rawdata/582898/4120288/
# no nutrition_data ../rawdata/582901/4120291/
# no nutrition_data ../rawdata/375673/3912952/
# no nutrition_data ../rawdata/375679/3912958/
# no nutrition_data ../rawdata/375676/3912955/
# no nutrition_data ../rawdata/88821/3625911/
# no nutrition_data ../rawdata/375685/3912964/
# no nutrition_data ../rawdata/88823/3625913/
# no nutrition_data ../rawdata/90215/3627305/
# no nutrition_data ../rawdata/382804/3920080/
# no nutrition_data ../rawdata/90015/3627105/
# no nutrition_data ../rawdata/91841/3628931/
# no nutrition_data ../rawdata/382219/3919495/
# no nutrition_data ../rawdata/90317/3627407/
# no nutrition_data ../rawdata/91219/3628309/
# no nutrition_data ../rawdata/515913/4053303/
# no nutrition_data ../rawdata/515916/4053306/
# no nutrition_data ../rawdata/382222/3919498/
# no nutrition_data ../rawdata/92745/3629835/
# no nutrition_data ../rawdata/382114/3919390/
# no nutrition_data ../rawdata/382120/3919396/
# no nutrition_data ../rawdata/91987/3629077/
# no nutrition_data ../rawdata/382132/3919408/
# no nutrition_data ../rawdata/495485/4032890/
# no nutrition_data ../rawdata/495482/4032887/
# no nutrition_data ../rawdata/495491/4032896/
# no nutrition_data ../rawdata/495488/4032893/
# no nutrition_data ../rawdata/418233/3955605/
# no nutrition_data ../rawdata/495437/4032845/
# no nutrition_data ../rawdata/92741/3629831/
# no nutrition_data ../rawdata/498169/4035574/
# no nutrition_data ../rawdata/375664/3912943/
# no nutrition_data ../rawdata/368740/3906019/
# no nutrition_data ../rawdata/375670/3912949/
# no nutrition_data ../rawdata/375667/3912946/
# no nutrition_data ../rawdata/538902/4076292/
# no nutrition_data ../rawdata/375682/3912961/
# no nutrition_data ../rawdata/479341/4016725/
# no nutrition_data ../rawdata/375688/3912967/
# no nutrition_data ../rawdata/382801/3920077/
# no nutrition_data ../rawdata/582985/4120375/
# no nutrition_data ../rawdata/582982/4120372/
# no nutrition_data ../rawdata/457626/3995019/
# no nutrition_data ../rawdata/432949/3970327/
# no nutrition_data ../rawdata/382816/3920092/
# no nutrition_data ../rawdata/382813/3920089/
# no nutrition_data ../rawdata/382807/3920083/
# no nutrition_data ../rawdata/382810/3920086/
# no nutrition_data ../rawdata/582979/4120369/
# no nutrition_data ../rawdata/382723/3919999/
# no nutrition_data ../rawdata/382726/3920002/
# no nutrition_data ../rawdata/432943/3970321/
# no nutrition_data ../rawdata/579519/4116909/
# no nutrition_data ../rawdata/382126/3919402/
# no nutrition_data ../rawdata/579516/4116906/
# no nutrition_data ../rawdata/579501/4116891/
# no nutrition_data ../rawdata/399701/3937022/
# no nutrition_data ../rawdata/399704/3937025/
# no nutrition_data ../rawdata/399695/3937016/
# no nutrition_data ../rawdata/399698/3937019/
# no nutrition_data ../rawdata/472185/4009560/
# no nutrition_data ../rawdata/472188/4009563/
# no nutrition_data ../rawdata/318707/3855998/
# no nutrition_data ../rawdata/311102/3848393/
# no nutrition_data ../rawdata/530449/4067839/
# no nutrition_data ../rawdata/318710/3856001/
# no nutrition_data ../rawdata/318713/3856004/
# no nutrition_data ../rawdata/520672/4058062/
# no nutrition_data ../rawdata/318605/3855896/
# no nutrition_data ../rawdata/318602/3855893/
# no nutrition_data ../rawdata/529639/4067029/
# no nutrition_data ../rawdata/318677/3855968/

# %%
conn.commit()

# %% [markdown]
# # Problems with nutrition data:
# - some products have no nutrition data
# - some products have nutrition data but it is not in the same format
#     - only kJ or kcal
